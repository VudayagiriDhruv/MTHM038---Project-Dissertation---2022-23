# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
O2_H1_L1_x=["GW170104","GW170608","GW170729","GW170809","GW170814","GW170817","GW170818","GW170823","GW190408_181802"]
O2_H1_L1_Chirp_mass=[27.37,28.22,27.88,28.07,27.51,27.56,28.25,27.43,27.75]
O2_H1_L1_Chirp_mass_lower_error=[0.86,0.65,1.00,0.57,0.63,0.78,0.57,0.79,0.66]
O2_H1_L1_Chirp_mass_upper_error=[0.86,0.62,1.04,0.56,0.64,0.76,0.59,0.82,0.70]
O2_H1_L1_Chirp_mass_asymmetric_error = [O2_H1_L1_Chirp_mass_lower_error, O2_H1_L1_Chirp_mass_upper_error]

O2_H1_L1_V1_x=["GW170104","GW170608","GW170729","GW170809","GW170814","GW170817","GW170818","GW170823","GW190408_181802"]
O2_H1_L1_V1_Chirp_mass=[27.37,28.22,27.88,28.07,27.51,27.56,28.25,27.43,27.75]
O2_H1_L1_V1_Chirp_mass_lower_error=[0.86,0.65,0.74,0.53,0.57,0.67,0.57,0.63,0.62]
O2_H1_L1_V1_Chirp_mass_upper_error=[0.86,0.62,0.79,0.56,0.55,0.64,0.55,0.62,0.58]
O2_H1_L1_V1_Chirp_mass_asymmetric_error = [O2_H1_L1_V1_Chirp_mass_lower_error, O2_H1_L1_V1_Chirp_mass_upper_error]

O3_H1_L1_V1_x=["GW190412","GW190413_052954","GW190413_134308","GW190421_213856","GW190425","GW190426_190642","GW190503_185404","GW190512_180714","GW190513_205428","GW190514_065416"]
O3_H1_L1_V1_Chirp_mass=[27.82,27.80,28.18,27.41,28.09,27.53,27.84,27.94,27.64,27.94]
O3_H1_L1_V1_Chirp_mass_lower_error=[0.53,0.62,0.58,0.63,0.54,0.68,0.60,0.58,0.70,0.52]
O3_H1_L1_V1_Chirp_mass_upper_error=[0.53,0.60,0.52,0.68,0.59,0.65,0.58,0.58,0.71,0.50]
O3_H1_L1_V1_Chirp_mass_asymmetric_error = [O3_H1_L1_V1_Chirp_mass_lower_error, O3_H1_L1_V1_Chirp_mass_upper_error]

fig, (ax0, ax1) = plt.subplots(nrows=2,figsize=(11,11),gridspec_kw={'wspace': 0.7})
ax0.errorbar(O2_H1_L1_x, O2_H1_L1_Chirp_mass, yerr=O2_H1_L1_Chirp_mass_asymmetric_error, fmt='-o',label="H1, L1",color='blue')
ax0.errorbar(O2_H1_L1_V1_x, O2_H1_L1_V1_Chirp_mass, yerr=O2_H1_L1_V1_Chirp_mass_asymmetric_error, fmt='-o',label="H1, L1, V1",color='red')
ax0.set_title('Analysis of O2 Injection and Chirp Mass with Asymmetric Error Estimation',fontweight='bold')
ax0.set_xticks(O2_H1_L1_x)
ax0.set_xlabel("Event",fontweight='bold')
ax0.set_ylabel("Chirp Mass",fontweight='bold')
ax0.set_xticklabels(O2_H1_L1_x,rotation=45)
ax0.legend()

ax1.errorbar(O3_H1_L1_V1_x, O3_H1_L1_V1_Chirp_mass, yerr=O3_H1_L1_V1_Chirp_mass_asymmetric_error, fmt='-o',label="H1, L1, V1",color='blue')
ax1.set_title('Analysis of O3 Injection and Chirp Mass with Asymmetric Error Estimation',fontweight='bold')
ax1.set_xlabel("Event",fontweight='bold')
ax1.set_ylabel("Chirp Mass",fontweight='bold')
ax1.set_xticklabels(O3_H1_L1_V1_x,rotation=45)
ax1.legend()

plt.subplots_adjust(wspace=0.4, hspace=0.8)

plt.savefig("chirp_mass.png")


plt.show();
# Out:
# /var/folders/bs/qjq7w_f90h920fjn19bxyjth0000gn/T/ipykernel_22995/1347941844.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(O3_H1_L1_V1_x,rotation=45)

# %%
O2_H1_L1_x=["GW170104","GW170608","GW170729","GW170809","GW170814","GW170817","GW170818","GW170823","GW190408_181802"]
O2_H1_L1_mass_ratio=[0.75,0.67,0.78,0.85,0.80,0.80,0.74,0.81,0.70]
O2_H1_L1_mass_ratio_lower_error=[0.16,0.11,0.16,0.14,0.17,0.16,0.14,0.16,0.14]
O2_H1_L1_mass_ratio_upper_error=[0.17,0.19,0.15,0.11,0.14,0.13,0.17,0.13,0.20]
O2_H1_L1_mass_ratio_asymmetric_error = [O2_H1_L1_mass_ratio_lower_error, O2_H1_L1_mass_ratio_upper_error]

O2_H1_L1_V1_x=["GW170104","GW170608","GW170729","GW170809","GW170814","GW170817","GW170818","GW170823","GW190408_181802"]
O2_H1_L1_V1_mass_ratio=[0.75,0.67,0.77,0.83,0.81,0.79,0.77,0.84,0.75]
O2_H1_L1_V1_mass_ratio_lower_error=[0.16,0.11,0.15,0.14,0.16,0.14,0.17,0.15,0.15]
O2_H1_L1_V1_mass_ratio_upper_error=[0.17,0.19,0.15,0.12,0.13,0.14,0.16,0.11,0.17]
O2_H1_L1_V1_mass_ratio_asymmetric_error = [O2_H1_L1_V1_mass_ratio_lower_error, O2_H1_L1_V1_mass_ratio_upper_error]

O3_H1_L1_V1_x=["GW190412","GW190413_052954","GW190413_134308","GW190421_213856","GW190425","GW190426_190642","GW190503_185404","GW190512_180714","GW190513_205428","GW190514_065416"]
O3_H1_L1_V1_mass_ratio=[0.67,0.68,0.68,0.81,0.82,0.80,0.83,0.84,0.74,0.86]
O3_H1_L1_V1_mass_ratio_lower_error=[0.11,0.12,0.12,0.16,0.15,0.14,0.15,0.14,0.14,0.13]
O3_H1_L1_V1_mass_ratio_upper_error=[0.18,0.20,0.19,0.13,0.12,0.14,0.11,0.11,0.17,0.09]
O3_H1_L1_V1_mass_ratio_asymmetric_error = [O3_H1_L1_V1_mass_ratio_lower_error, O3_H1_L1_V1_mass_ratio_upper_error]

fig, (ax0, ax1) = plt.subplots(nrows=2,figsize=(11,11),gridspec_kw={'wspace': 0.7})
ax0.errorbar(O2_H1_L1_x, O2_H1_L1_mass_ratio, yerr=O2_H1_L1_mass_ratio_asymmetric_error, fmt='-o',label="H1, L1",color='blue')
ax0.errorbar(O2_H1_L1_V1_x, O2_H1_L1_V1_mass_ratio, yerr=O2_H1_L1_V1_mass_ratio_asymmetric_error, fmt='-o',label="H1, L1, V1",color='red')
ax0.set_title('Analysis of O2 Injection and Mass Ratio with Asymmetric Error Estimation',fontweight='bold')
ax0.set_xticks(O2_H1_L1_x)
ax0.set_xlabel("Event",fontweight='bold')
ax0.set_ylabel("mass ratio",fontweight='bold')
ax0.set_xticklabels(O2_H1_L1_x,rotation=45)
ax0.legend()

ax1.errorbar(O3_H1_L1_V1_x, O3_H1_L1_V1_mass_ratio, yerr=O3_H1_L1_V1_mass_ratio_asymmetric_error, fmt='-o',label="H1, L1, V1",color='blue')
ax1.set_title('Analysis of O3 Injection and Mass Ratio with Asymmetric Error Estimation',fontweight='bold')
ax1.set_xlabel("Event",fontweight='bold')
ax1.set_ylabel("mass ratio",fontweight='bold')
ax1.set_xticklabels(O3_H1_L1_V1_x,rotation=45)
ax1.legend()

plt.subplots_adjust(wspace=0.4, hspace=0.8)

plt.savefig("mass_ratio.png")

plt.show();
# Out:
# /var/folders/bs/qjq7w_f90h920fjn19bxyjth0000gn/T/ipykernel_22995/3915727611.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(O3_H1_L1_V1_x,rotation=45)

# %%
O2_H1_L1_x=["GW170104","GW170608","GW170729","GW170809","GW170814","GW170817","GW170818","GW170823","GW190408_181802"]
O2_H1_L1_Spin1=[0.42,0.58,0.51,0.61,0.45,0.48,0.48,0.46,0.44]
O2_H1_L1_Spin1_lower_error=[0.26,0.28,0.29,0.30,0.27,0.30,0.28,0.30,0.27]
O2_H1_L1_Spin1_upper_error=[0.29,0.22,0.28,0.25,0.29,0.27,0.25,0.31,0.26]
O2_H1_L1_Spin1_asymmetric_error = [O2_H1_L1_Spin1_lower_error, O2_H1_L1_Spin1_upper_error]

O2_H1_L1_V1_x=["GW170104","GW170608","GW170729","GW170809","GW170814","GW170817","GW170818","GW170823","GW190408_181802"]
O2_H1_L1_V1_Spin1=[0.42,0.58,0.48,0.58,0.44,0.44,0.54,0.45,0.44]
O2_H1_L1_V1_Spin1_lower_error=[0.26,0.28,0.29,0.30,0.26,0.26,0.31,0.28,0.26]
O2_H1_L1_V1_Spin1_upper_error=[0.29,0.22,0.25,0.25,0.27,0.28,0.34,0.26,0.26]
O2_H1_L1_V1_Spin1_asymmetric_error = [O2_H1_L1_V1_Spin1_lower_error, O2_H1_L1_V1_Spin1_upper_error]

O3_H1_L1_V1_x=["GW190412","GW190413_052954","GW190413_134308","GW190421_213856","GW190425","GW190426_190642","GW190503_185404","GW190512_180714","GW190513_205428","GW190514_065416"]
O3_H1_L1_V1_Spin1=[0.41,0.50,0.49,0.43,0.66,0.50,0.52,0.55,0.43,0.63]
O3_H1_L1_V1_Spin1_lower_error=[0.25,0.29,0.28,0.28,0.33,0.28,0.31,0.30,0.26,0.32]
O3_H1_L1_V1_Spin1_upper_error=[0.26,0.25,0.22,0.26,0.24,0.28,0.27,0.26,0.29,0.24]
O3_H1_L1_V1_Spin1_asymmetric_error = [O3_H1_L1_V1_Spin1_lower_error, O3_H1_L1_V1_Spin1_upper_error]

fig, (ax0, ax1) = plt.subplots(nrows=2,figsize=(11,11),gridspec_kw={'wspace': 0.7})
ax0.errorbar(O2_H1_L1_x, O2_H1_L1_Spin1, yerr=O2_H1_L1_Spin1_asymmetric_error, fmt='-o',label="H1, L1",color='blue')
ax0.errorbar(O2_H1_L1_V1_x, O2_H1_L1_V1_Spin1, yerr=O2_H1_L1_V1_Spin1_asymmetric_error, fmt='-o',label="H1, L1, V1",color='red')
ax0.set_title('Analysis of O2 Injection and Spin1 with Asymmetric Error Estimation',fontweight='bold')
ax0.set_xticks(O2_H1_L1_x)
ax0.set_xlabel("Event",fontweight='bold')
ax0.set_ylabel("Spin1",fontweight='bold')
ax0.set_xticklabels(O2_H1_L1_x,rotation=45)
ax0.legend()

ax1.errorbar(O3_H1_L1_V1_x, O3_H1_L1_V1_Spin1, yerr=O3_H1_L1_V1_Spin1_asymmetric_error, fmt='-o',label="H1, L1, V1",color='blue')
ax1.set_title('Analysis of O3 Injection and Spin1 with Asymmetric Error Estimation',fontweight='bold')
ax1.set_xlabel("Event",fontweight='bold')
ax1.set_ylabel("Spin1",fontweight='bold')
ax1.set_xticklabels(O3_H1_L1_V1_x,rotation=45)
ax1.legend()

plt.subplots_adjust(wspace=0.4, hspace=0.8)

plt.savefig("spin1.png")

plt.show();
# Out:
# /var/folders/bs/qjq7w_f90h920fjn19bxyjth0000gn/T/ipykernel_22995/3880026907.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(O3_H1_L1_V1_x,rotation=45)

# %%
O2_H1_L1_x=["GW170104","GW170608","GW170729","GW170809","GW170814","GW170817","GW170818","GW170823","GW190408_181802"]
O2_H1_L1_Spin2=[0.52,0.57,0.52,0.49,0.51,0.48,0.54,0.50,0.53]
O2_H1_L1_Spin2_lower_error=[0.32,0.36,0.34,0.32,0.32,0.31,0.34,0.32,0.33]
O2_H1_L1_Spin2_upper_error=[0.30,0.28,0.30,0.30,0.31,0.31,0.29,0.31,0.31]
O2_H1_L1_Spin2_asymmetric_error = [O2_H1_L1_Spin2_lower_error, O2_H1_L1_Spin2_upper_error]

O2_H1_L1_V1_x=["GW170104","GW170608","GW170729","GW170809","GW170814","GW170817","GW170818","GW170823","GW190408_181802"]
O2_H1_L1_V1_Spin2=[0.52,0.57,0.51,0.48,0.48,0.47,0.57,0.47,0.50]
O2_H1_L1_V1_Spin2_lower_error=[0.32,0.36,0.33,0.32,0.31,0.31,0.37,0.31,0.32]
O2_H1_L1_V1_Spin2_upper_error=[0.30,0.28,0.29,0.31,0.29,0.30,0.27,0.30,0.30]
O2_H1_L1_V1_Spin2_asymmetric_error = [O2_H1_L1_V1_Spin2_lower_error, O2_H1_L1_V1_Spin2_upper_error]

O3_H1_L1_V1_x=["GW190412","GW190413_052954","GW190413_134308","GW190421_213856","GW190425","GW190426_190642","GW190503_185404","GW190512_180714","GW190513_205428","GW190514_065416"]
O3_H1_L1_V1_Spin2=[0.55,0.56,0.51,0.46,0.53,0.50,0.48,0.49,0.49,0.54]
O3_H1_L1_V1_Spin2_lower_error=[0.33,0.36,0.33,0.28,0.36,0.32,0.32,0.33,0.32,0.34]
O3_H1_L1_V1_Spin2_upper_error=[0.29,0.29,0.29,0.31,0.30,0.30,0.30,0.32,0.30,0.28]
O3_H1_L1_V1_Spin2_asymmetric_error = [O3_H1_L1_V1_Spin2_lower_error, O3_H1_L1_V1_Spin2_upper_error]

fig, (ax0, ax1) = plt.subplots(nrows=2,figsize=(11,11),gridspec_kw={'wspace': 0.7})
ax0.errorbar(O2_H1_L1_x, O2_H1_L1_Spin2, yerr=O2_H1_L1_Spin2_asymmetric_error, fmt='-o',label="H1, L1",color='blue')
ax0.errorbar(O2_H1_L1_V1_x, O2_H1_L1_V1_Spin2, yerr=O2_H1_L1_V1_Spin2_asymmetric_error, fmt='-o',label="H1, L1, V1",color='red')
ax0.set_title('Analysis of O2 Injection and Spin2 with Asymmetric Error Estimation',fontweight='bold')
ax0.set_xticks(O2_H1_L1_x)
ax0.set_xlabel("Event",fontweight='bold')
ax0.set_ylabel("Spin2",fontweight='bold')
ax0.set_xticklabels(O2_H1_L1_x,rotation=45)
ax0.legend()

ax1.errorbar(O3_H1_L1_V1_x, O3_H1_L1_V1_Spin2, yerr=O3_H1_L1_V1_Spin2_asymmetric_error, fmt='-o',label="H1, L1, V1",color='blue')
ax1.set_title('Analysis of O3 Injection and Spin2 with Asymmetric Error Estimation',fontweight='bold')
ax1.set_xlabel("Event",fontweight='bold')
ax1.set_ylabel("Spin2",fontweight='bold')
ax1.set_xticklabels(O3_H1_L1_V1_x,rotation=45)
ax1.legend()

plt.subplots_adjust(wspace=0.4, hspace=0.8)

plt.savefig("spin2.png")

plt.show();
# Out:
# /var/folders/bs/qjq7w_f90h920fjn19bxyjth0000gn/T/ipykernel_22995/2414706044.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(O3_H1_L1_V1_x,rotation=45)
