# %% [markdown]
# # Injection week5

# %% [markdown]
# ### Instalization

# %%
! pip install -q 'cpnest'

# %%
! pip install --upgrade cpnest
# Out:
# Requirement already satisfied: cpnest in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (0.11.5)
# Requirement already satisfied: numpy in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from cpnest) (1.24.3)
# Requirement already satisfied: scipy in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from cpnest) (1.9.3)
# Requirement already satisfied: corner in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from cpnest) (2.2.2)
# Requirement already satisfied: tqdm in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from cpnest) (4.65.0)
# Requirement already satisfied: cython in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from cpnest) (0.29.34)
# Requirement already satisfied: matplotlib in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from cpnest) (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from matplotlib->cpnest) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from matplotlib->cpnest) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from matplotlib->cpnest) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from matplotlib->cpnest) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from matplotlib->cpnest) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from matplotlib->cpnest) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from matplotlib->cpnest) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from matplotlib->cpnest) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->cpnest) (1.16.0)

# %%
#!/usr/bin/env python
"""
Tutorial to demonstrate running parameter estimation on a full 15 parameter
space for an injected cbc signal. This is the standard injection analysis script
one can modify for the study of injected CBC events.
"""
import numpy as np
import bilby

# Set the duration and sampling frequency of the data segment that we're
# going to inject the signal into
duration = 4.
sampling_frequency = 2048.

# Specify the output directory and the name of the simulation.
outdir = 'outdir'
label = 'full_15_parameters'
bilby.core.utils.setup_logger(outdir=outdir, label=label)

# %% [markdown]
# ### Data Setup

# %%
# Set up a random seed for result reproducibility.  This is optional!
np.random.seed(88170235)

# We are going to inject a binary black hole waveform.  We first establish a
# dictionary of parameters that includes all of the different waveform
# parameters, including masses of the two black holes (mass_1, mass_2),
# spins of both black holes (a, tilt, phi), etc.
injection_parameters = dict(
    mass_1=36., mass_2=29., a_1=0.4, a_2=0.3, tilt_1=0.5, tilt_2=1.0,
    phi_12=1.7, phi_jl=0.3, luminosity_distance=2000., theta_jn=0.4, psi=2.659,
    phase=1.3, geocent_time=1126259642.413, ra=1.375, dec=-1.2108)

# %% [markdown]
# ### Create a waveform generator

# %%
# Fixed arguments passed into the source model
waveform_arguments = dict(waveform_approximant='IMRPhenomPv2',
                          reference_frequency=50., minimum_frequency=20.)

# Create the waveform_generator using a LAL BinaryBlackHole source function
# the generator will convert all the parameters
waveform_generator = bilby.gw.WaveformGenerator(
    duration=duration, sampling_frequency=sampling_frequency,
    frequency_domain_source_model=bilby.gw.source.lal_binary_black_hole,
    parameter_conversion=bilby.gw.conversion.convert_to_lal_binary_black_hole_parameters,
    waveform_arguments=waveform_arguments)

# Set up interferometers.  In this case we'll use two interferometers
# (LIGO-Hanford (H1), LIGO-Livingston (L1). These default to their design
# sensitivity
ifos = bilby.gw.detector.InterferometerList(['H1', 'L1'])
ifos.set_strain_data_from_power_spectral_densities(
    sampling_frequency=sampling_frequency, duration=duration,
    start_time=injection_parameters['geocent_time'] - 3)

ifos.inject_signal(waveform_generator=waveform_generator,
                   parameters=injection_parameters)
# Out:
# 22:31 bilby INFO    : Waveform generator initiated with
#   frequency_domain_source_model: bilby.gw.source.lal_binary_black_hole
#   time_domain_source_model: None
#   parameter_conversion: bilby.gw.conversion.convert_to_lal_binary_black_hole_parameters
# 22:31 bilby INFO    : Injected signal in H1:
# 22:31 bilby INFO    :   optimal SNR = 11.78
# 22:31 bilby INFO    :   matched filter SNR = 12.82-2.04j
# 22:31 bilby INFO    :   mass_1 = 36.0
# 22:31 bilby INFO    :   mass_2 = 29.0
# 22:31 bilby INFO    :   a_1 = 0.4
# 22:31 bilby INFO    :   a_2 = 0.3
# 22:31 bilby INFO    :   tilt_1 = 0.5
# 22:31 bilby INFO    :   tilt_2 = 1.0
# 22:31 bilby INFO    :   phi_12 = 1.7
# 22:31 bilby INFO    :   phi_jl = 0.3
# 22:31 bilby INFO    :   luminosity_distance = 2000.0
# 22:31 bilby INFO    :   theta_jn = 0.4
# 22:31 bilby INFO    :   psi = 2.659
# 22:31 bilby INFO    :   phase = 1.3
# 22:31 bilby INFO    :   geocent_time = 1126259642.413
# 22:31 bilby INFO    :   ra = 1.375
# 22:31 bilby INFO    :   dec = -1.2108
# 22:31 bilby INFO    : Injected signal in L1:
# 22:31 bilby INFO    :   optimal SNR = 9.53
# 22:31 bilby INFO    :   matched filter SNR = 10.03+0.04j
# 22:31 bilby INFO    :   mass_1 = 36.0
# 22:31 bilby INFO    :   mass_2 = 29.0
# 22:31 bilby INFO    :   a_1 = 0.4
# 22:31 bilby INFO    :   a_2 = 0.3
# 22:31 bilby INFO    :   tilt_1 = 0.5
# 22:31 bilby INFO    :   tilt_2 = 1.0
# 22:31 bilby INFO    :   phi_12 = 1.7
# 22:31 bilby INFO    :   phi_jl = 0.3
# 22:31 bilby INFO    :   luminosity_distance = 2000.0
# 22:31 bilby INFO    :   theta_jn = 0.4
# 22:31 bilby INFO    :   psi = 2.659
# 22:31 bilby INFO    :   phase = 1.3
# 22:31 bilby INFO    :   geocent_time = 1126259642.413
# 22:31 bilby INFO    :   ra = 1.375
# 22:31 bilby INFO    :   dec = -1.2108
# [{'plus': array([0.-0.j, 0.-0.j, 0.-0.j, ..., 0.-0.j, 0.-0.j, 0.-0.j]),
#   'cross': array([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j])},
#  {'plus': array([0.-0.j, 0.-0.j, 0.-0.j, ..., 0.-0.j, 0.-0.j, 0.-0.j]),
#   'cross': array([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j])}]

# %% [markdown]
# ### Create a prior

# %%
# For this analysis, we implement the standard BBH priors defined, except for
# the definition of the time prior, which is defined as uniform about the
# injected value.
# Furthermore, we decide to sample in chirp mass and mass ratio, due to the
# preferred shape for the associated posterior distributions.
priors = bilby.gw.prior.BBHPriorDict()
priors.pop('mass_1')
priors.pop('mass_2')

priors['chirp_mass'] = bilby.prior.Uniform(
    name='chirp_mass', latex_label='$M$', minimum=10.0, maximum=100.0,
    unit='$M_{\\odot}$')

priors['mass_ratio'] = bilby.prior.Uniform(
    name='mass_ratio', latex_label='$q$', minimum=0.5, maximum=1.0)

priors['geocent_time'] = bilby.core.prior.Uniform(
    minimum=injection_parameters['geocent_time'] - 0.1,
    maximum=injection_parameters['geocent_time'] + 0.1,
    name='geocent_time', latex_label='$t_c$', unit='$s$')
# Out:
# 22:31 bilby INFO    : No prior given, using default BBH priors in /Users/dhruv/miniconda3/envs/igwn-py39/lib/python3.9/site-packages/bilby/gw/prior_files/precessing_spins_bbh.prior.

# %% [markdown]
# ### Create a likelihood

# %%
# Initialise the likelihood by passing in the interferometer data (ifos) and
# the waveoform generator, as well the priors.
# The explicit time, distance, and phase marginalizations are turned on to
# improve convergence, and the parameters are recovered by the conversion
# function.
likelihood = bilby.gw.GravitationalWaveTransient(
    interferometers=ifos, waveform_generator=waveform_generator, priors=priors,
    distance_marginalization=True, phase_marginalization=True, time_marginalization=True)
# Out:
# 22:32 bilby INFO    : Loaded distance marginalisation lookup table from .distance_marginalization_lookup.npz.

# %%
# Run sampler. In this case we're going to use the `cpnest` sampler
# Note that the maxmcmc parameter is increased so that between each iteration of
# the nested sampler approach, the walkers will move further using an mcmc
# approach, searching the full parameter space.
# The conversion function will determine the distance, phase and coalescence
# time posteriors in post processing.
result = bilby.run_sampler(
    likelihood=likelihood, priors=priors, sampler='dynesty', npoints=2000,
    injection_parameters=injection_parameters, outdir=outdir,
    label=label, maxmcmc=2000,
    conversion_function=bilby.gw.conversion.generate_all_bbh_parameters)

# Make a corner plot.
result.plot_corner()
# Out:
# 12:29 bilby INFO    : Running for label 'full_15_parameters', output will be saved to 'outdir'
# 12:29 bilby INFO    : Using lal version 7.2.4
# 12:29 bilby INFO    : Using lal git version Branch: None;Tag: lalsuite-v7.11;Id: 7a2f2aa176ad39eeaede38f6df4a41d6bf226e8f;;Builder: Unknown User <>;Repository status: CLEAN: All modifications committed
# 12:29 bilby INFO    : Using lalsimulation version 4.0.2
# 12:29 bilby INFO    : Using lalsimulation git version Branch: None;Tag: lalsuite-v7.11;Id: 7a2f2aa176ad39eeaede38f6df4a41d6bf226e8f;;Builder: Unknown User <>;Repository status: CLEAN: All modifications committed
# 12:29 bilby INFO    : Analysis priors:
# 12:29 bilby INFO    : mass_ratio=Uniform(minimum=0.5, maximum=1.0, name='mass_ratio', latex_label='$q$', unit=None, boundary=None)
# 12:29 bilby INFO    : chirp_mass=Uniform(minimum=10.0, maximum=100.0, name='chirp_mass', latex_label='$M$', unit='$M_{\\odot}$', boundary=None)
# 12:29 bilby INFO    : dec=Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None)
# 12:29 bilby INFO    : ra=Uniform(minimum=0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic')
# 12:29 bilby INFO    : theta_jn=Sine(minimum=0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None)
# 12:29 bilby INFO    : psi=Uniform(minimum=0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')
# 12:29 bilby INFO    : a_1=Uniform(minimum=0, maximum=0.99, name='a_1', latex_label='$a_1$', unit=None, boundary=None)
# 12:29 bilby INFO    : a_2=Uniform(minimum=0, maximum=0.99, name='a_2', latex_label='$a_2$', unit=None, boundary=None)
# 12:29 bilby INFO    : tilt_1=Sine(minimum=0, maximum=3.141592653589793, name='tilt_1', latex_label='$\\theta_1$', unit=None, boundary=None)
# 12:29 bilby INFO    : tilt_2=Sine(minimum=0, maximum=3.141592653589793, name='tilt_2', latex_label='$\\theta_2$', unit=None, boundary=None)
# 12:29 bilby INFO    : phi_12=Uniform(minimum=0, maximum=6.283185307179586, name='phi_12', latex_label='$\\Delta\\phi$', unit=None, boundary='periodic')
# 12:29 bilby INFO    : phi_jl=Uniform(minimum=0, maximum=6.283185307179586, name='phi_jl', latex_label='$\\phi_{JL}$', unit=None, boundary='periodic')
# 12:29 bilby INFO    : time_jitter=Uniform(minimum=-0.00048828125, maximum=0.00048828125, name='time_jitter', latex_label='$t_j$', unit=None, boundary='periodic')
# 12:29 bilby INFO    : luminosity_distance=3382.9535676089
# 12:29 bilby INFO    : phase=0.0
# 12:29 bilby INFO    : geocent_time=1126259639.413
# 12:29 bilby INFO    : Analysis likelihood class: <class 'bilby.gw.likelihood.base.GravitationalWaveTransient'>
# 12:29 bilby INFO    : Analysis likelihood noise evidence: -8111.161748397944
# 12:29 bilby INFO    : Single likelihood evaluation took 4.904e-03 s
# 12:29 bilby INFO    : Using sampler Dynesty with kwargs {'nlive': 2000, 'bound': 'live', 'sample': 'act-walk', 'periodic': None, 'reflective': None, 'update_interval': 600, 'first_update': None, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'gradient': None, 'grad_args': None, 'grad_kwargs': None, 'compute_jac': False, 'enlarge': None, 'bootstrap': None, 'walks': 100, 'facc': 0.2, 'slices': None, 'fmove': 0.9, 'max_move': 100, 'update_func': None, 'ncdim': None, 'blob': False, 'save_history': False, 'history_filename': None, 'maxiter': None, 'maxcall': None, 'dlogz': 0.1, 'logl_max': inf, 'n_effective': None, 'add_live': True, 'print_progress': True, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x15cac0520>>, 'save_bounds': False, 'checkpoint_file': None, 'checkpoint_every': 60, 'resume': False}
# 12:29 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 12:29 bilby INFO    : Using dynesty version 2.1.1
# 12:29 bilby INFO    : Using the bilby-implemented rwalk sampling tracking the autocorrelation function and thinning by 2 with maximum length 4000
# 12:29 bilby INFO    : Resume file outdir/full_15_parameters_resume.pickle does not exist.
# 12:29 bilby INFO    : Generating initial points from the prior
# 1it [00:00, ?it/s]
# 12:40 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 12:51 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:01 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:12 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:24 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:36 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:47 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:58 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 14:09 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 14:19 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 14:30 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 14:41 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 14:55 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:06 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:18 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:30 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:49 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:00 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:12 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:24 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:35 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:46 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:57 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:09 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:20 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:32 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:42 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:53 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 18:19 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 19:01 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 20:19 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 20:31 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 20:44 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 20:56 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 21:07 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 21:19 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 21:29 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 22:11 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 22:22 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 22:59 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 23:11 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 23:31 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 23:50 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 01:20 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 01:48 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 02:51 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 03:56 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 05:03 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 06:07 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 06:29 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 07:06 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 07:33 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 07:52 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 08:06 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 09:16 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 09:56 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 10:59 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 11:09 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 11:21 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 11:32 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 11:44 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 11:55 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 12:05 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 12:17 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 12:27 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 12:38 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 12:50 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:01 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:12 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:23 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:34 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 13:50 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 14:23 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 14:50 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:07 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:19 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:33 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:43 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 15:55 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:18 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:29 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:41 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 16:53 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:05 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:16 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:34 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 17:45 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 18:59 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 19:18 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 19:33 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 19:45 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 20:15 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 20:26 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 20:38 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 20:48 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 21:15 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 21:26 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle
# 21:36 bilby INFO    : Written checkpoint file outdir/full_15_parameters_resume.pickle

# %%
samples = result.posterior

# %%
samples
# Out:
#      mass_ratio  chirp_mass       a_1       a_2    tilt_1    tilt_2    phi_12
# 0      0.836028   31.725626  0.662000  0.645164  1.615677  1.726965  4.926762  \
# 1      0.875399   31.063765  0.132188  0.105331  1.358270  1.928139  0.768192
# 2      0.999707   30.428421  0.920642  0.382177  2.155972  0.662301  4.522789
# 3      0.859521   32.893418  0.125905  0.289173  0.897341  1.349229  6.121069
# 4      0.558228   31.036358  0.316932  0.047103  1.311152  1.040560  4.302064
# ..          ...         ...       ...       ...       ...       ...       ...
# 525    0.992363   31.309936  0.163289  0.437566  0.156190  1.952186  1.435859
# 526    0.896271   31.112798  0.461017  0.397027  1.125093  2.281037  4.242951
# 527    0.880654   30.833658  0.752558  0.875270  2.071190  1.219948  4.574085
# 528    0.991459   30.882850  0.270110  0.941317  3.016109  1.445538  2.010849
# 529    0.894649   30.420744  0.706310  0.841501  0.704509  2.765511  2.406512
#
#        phi_jl       dec        ra  ...  chi_2_in_plane     chi_p  cos_tilt_1
# 0    4.825046 -0.967467  2.555441  ...        0.637312  0.661333   -0.044866  \
# 1    2.507927 -1.311102  1.566008  ...        0.098677  0.129214    0.210930
# 2    3.088706 -0.739912  2.712823  ...        0.235013  0.767461   -0.552346
# 3    0.280472 -1.119265  2.255562  ...        0.282104  0.237297    0.623690
# 4    5.536851 -1.277885  1.596640  ...        0.040636  0.306309    0.256736
# ..        ...       ...       ...  ...             ...       ...         ...
# 525  6.124195 -1.270721  2.015710  ...        0.406126  0.402584    0.987827
# 526  3.958598 -1.270887  1.620534  ...        0.301028  0.415980    0.431092
# 527  3.781005 -1.247400  2.172724  ...        0.821950  0.710847   -0.479771
# 528  1.798495 -1.244329  2.093363  ...        0.933943  0.924832   -0.992137
# 529  1.746670 -1.268648  1.852380  ...        0.309065  0.457448    0.761930
#
#      cos_tilt_2  redshift  comoving_distance  mass_1_source  mass_2_source
# 0     -0.155535  0.117237         504.464714      35.703288      29.848952  \
# 1     -0.349786  0.075153         326.726022      35.487797      31.065973
# 2      0.788580  0.108361         467.292231      31.540449      31.531218
# 3      0.219759  0.111736         481.448616      36.680348      31.527542
# 4      0.505737  0.096663         418.045661      43.876976      24.493373
# ..          ...       ...                ...            ...            ...
# 525   -0.372210  0.118259         508.734199      32.285758      32.039202
# 526   -0.652016  0.110091         474.550314      34.017081      30.488530
# 527    0.343695  0.109967         474.030173      34.016824      29.957046
# 528    0.124931  0.109807         473.361294      32.102534      31.828341
# 529   -0.930111  0.115067         495.393151      33.142324      29.650747
#
#      chirp_mass_source total_mass_source
# 0            28.396504         65.552239
# 1            28.892417         66.553770
# 2            27.453537         63.071667
# 3            29.587428         68.207890
# 4            28.300728         68.370348
# ..                 ...               ...
# 525          27.998818         64.324960
# 526          28.027258         64.505611
# 527          27.778905         63.973870
# 528          27.827223         63.930875
# 529          27.281536         62.793071
#
# [530 rows x 52 columns]

# %%
type(samples)
# Out:
# pandas.core.frame.DataFrame

# %%
samples.columns.tolist()[:13]
# Out:
# ['mass_ratio',
#  'chirp_mass',
#  'a_1',
#  'a_2',
#  'tilt_1',
#  'tilt_2',
#  'phi_12',
#  'phi_jl',
#  'dec',
#  'ra',
#  'theta_jn',
#  'psi',
#  'time_jitter']
