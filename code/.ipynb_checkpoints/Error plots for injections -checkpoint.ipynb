# %% [markdown]
# # parameter estimation on GW150914

# %% [markdown]
# ### Instalization

# %%
import bilby
from gwpy.timeseries import TimeSeries

logger = bilby.core.utils.logger
outdir = 'outdir'
label = 'GW150914'

# %% [markdown]
# ### Data Setup

# %%
trigger_time = 1126259462

roll_off = 0.4  # Roll off duration of tukey window in seconds, default is 0.4s
duration = 4  # Analysis segment duration
post_trigger_duration = 2  # Time between trigger time and end of segment
end_time = trigger_time + post_trigger_duration
start_time = end_time - duration

psd_duration = 32 * duration
psd_start_time = start_time - psd_duration
psd_end_time = start_time

# %% [markdown]
# ### Download the data

# %%
# We now use gwpy to obtain analysis and psd data and create the ifo_list
ifo_list = bilby.gw.detector.InterferometerList([])
for det in ["H1", "L1"]:
    logger.info("Downloading analysis data for ifo {}".format(det))
    ifo = bilby.gw.detector.get_empty_interferometer(det)
    data = TimeSeries.fetch_open_data(det, start_time, end_time)
    ifo.strain_data.set_from_gwpy_timeseries(data)

    logger.info("Downloading psd data for ifo {}".format(det))
    psd_data = TimeSeries.fetch_open_data(det, psd_start_time, psd_end_time)
    psd_alpha = 2 * roll_off / duration
    psd = psd_data.psd(
        fftlength=duration,
        overlap=0,
        window=("tukey", psd_alpha),
        method="median"
    )
    ifo.power_spectral_density = bilby.gw.detector.PowerSpectralDensity(
        frequency_array=psd.frequencies.value, psd_array=psd.value)
    ifo_list.append(ifo)

logger.info("Saving data plots to {}".format(outdir))
bilby.core.utils.check_directory_exists_and_if_not_mkdir(outdir)
ifo_list.plot_data(outdir=outdir, label=label)
# Out:
# 13:03 bilby INFO    : Downloading analysis data for ifo H1
# 13:03 bilby INFO    : Downloading psd data for ifo H1
# 13:07 bilby INFO    : Downloading analysis data for ifo L1
# 13:07 bilby INFO    : Downloading psd data for ifo L1
# 13:10 bilby INFO    : Saving data plots to outdir
# 13:10 bilby INFO    : Generating frequency domain strain from given time domain strain.
# 13:10 bilby INFO    : Applying a tukey window with alpha=0.1, roll off=0.2
# 13:10 bilby INFO    : Generating frequency domain strain from given time domain strain.
# 13:10 bilby INFO    : Applying a tukey window with alpha=0.1, roll off=0.2

# %% [markdown]
# ### Create a prior

# %%
# We now define the prior.
# We have defined our prior distribution in a local file, GW150914.prior
# The prior is printed to the terminal at run-time.
# You can overwrite this using the syntax below in the file,
# or choose a fixed value by just providing a float value as the prior.
priors = bilby.gw.prior.BBHPriorDict(filename='GW150914.prior')

# %% [markdown]
# ### Create a waveform generator

# %%
# In this step we define a `waveform_generator`. This is the object which
# creates the frequency-domain strain. In this instance, we are using the
# `lal_binary_black_hole model` source model. We also pass other parameters:
# the waveform approximant and reference frequency and a parameter conversion
# which allows us to sample in chirp mass and ratio rather than component mass
waveform_generator = bilby.gw.WaveformGenerator(
    frequency_domain_source_model=bilby.gw.source.lal_binary_black_hole,
    parameter_conversion=bilby.gw.conversion.convert_to_lal_binary_black_hole_parameters,
    waveform_arguments={'waveform_approximant': 'IMRPhenomPv2',
                        'reference_frequency': 50})
# Out:
# 13:10 bilby INFO    : Waveform generator initiated with
#   frequency_domain_source_model: bilby.gw.source.lal_binary_black_hole
#   time_domain_source_model: None
#   parameter_conversion: bilby.gw.conversion.convert_to_lal_binary_black_hole_parameters

# %% [markdown]
# ### Create a likelihood

# %%
# In this step, we define the likelihood. Here we use the standard likelihood
# function, passing it the data and the waveform generator.
likelihood = bilby.gw.likelihood.GravitationalWaveTransient(
    ifo_list, waveform_generator, priors=priors, time_marginalization=True,
    phase_marginalization=True, distance_marginalization=True)
# Out:
# 13:10 bilby WARNING : Prior not provided for geocent_time, using the BBH default.
# 13:10 bilby INFO    : Loaded distance marginalisation lookup table from .distance_marginalization_lookup.npz.

# %% [markdown]
# ### Run the analysis

# %%
# Finally, we run the sampler. This function takes the likelihood and prior
# along with some options for how to do the sampling and how to save the data
result = bilby.run_sampler(
    likelihood, priors, sampler='dynesty', outdir=outdir, label=label,
    nlive=1000, walks=100, n_check_point=10000, check_point_plot=True,
    conversion_function=bilby.gw.conversion.generate_all_bbh_parameters)
result.plot_corner()
# Out:
# 13:10 bilby INFO    : Running for label 'GW150914', output will be saved to 'outdir'
# 13:10 bilby INFO    : Using lal version 7.2.4
# 13:10 bilby INFO    : Using lal git version Branch: None;Tag: lalsuite-v7.11;Id: 7a2f2aa176ad39eeaede38f6df4a41d6bf226e8f;;Builder: Unknown User <>;Repository status: CLEAN: All modifications committed
# 13:10 bilby INFO    : Using lalsimulation version 4.0.2
# 13:10 bilby INFO    : Using lalsimulation git version Branch: None;Tag: lalsuite-v7.11;Id: 7a2f2aa176ad39eeaede38f6df4a41d6bf226e8f;;Builder: Unknown User <>;Repository status: CLEAN: All modifications committed
# 13:10 bilby INFO    : Analysis priors:
# 13:10 bilby INFO    : mass_ratio=bilby.gw.prior.UniformInComponentsMassRatio(minimum=0.125, maximum=1, name='mass_ratio', latex_label='$q$', unit=None, boundary=None, equal_mass=False)
# 13:10 bilby INFO    : chirp_mass=bilby.gw.prior.UniformInComponentsChirpMass(minimum=25, maximum=35, name='chirp_mass', latex_label='$\\mathcal{M}$', unit=None, boundary=None)
# 13:10 bilby INFO    : a_1=Uniform(minimum=0, maximum=0.99, name='a_1', latex_label='$a_1$', unit=None, boundary=None)
# 13:10 bilby INFO    : a_2=Uniform(minimum=0, maximum=0.99, name='a_2', latex_label='$a_2$', unit=None, boundary=None)
# 13:10 bilby INFO    : tilt_1=Sine(minimum=0, maximum=3.141592653589793, name='tilt_1', latex_label='$\\theta_1$', unit=None, boundary=None)
# 13:10 bilby INFO    : tilt_2=Sine(minimum=0, maximum=3.141592653589793, name='tilt_2', latex_label='$\\theta_2$', unit=None, boundary=None)
# 13:10 bilby INFO    : phi_12=Uniform(minimum=0, maximum=6.283185307179586, name='phi_12', latex_label='$\\Delta\\phi$', unit=None, boundary='periodic')
# 13:10 bilby INFO    : phi_jl=Uniform(minimum=0, maximum=6.283185307179586, name='phi_jl', latex_label='$\\phi_{JL}$', unit=None, boundary='periodic')
# 13:10 bilby INFO    : dec=Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='dec', latex_label='$\\mathrm{DEC}$', unit=None, boundary=None)
# 13:10 bilby INFO    : ra=Uniform(minimum=0, maximum=6.283185307179586, name='ra', latex_label='$\\mathrm{RA}$', unit=None, boundary='periodic')
# 13:10 bilby INFO    : theta_jn=Sine(minimum=0, maximum=3.141592653589793, name='theta_jn', latex_label='$\\theta_{JN}$', unit=None, boundary=None)
# 13:10 bilby INFO    : psi=Uniform(minimum=0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')
# 13:10 bilby INFO    : time_jitter=Uniform(minimum=-0.000244140625, maximum=0.000244140625, name='time_jitter', latex_label='$t_j$', unit=None, boundary='periodic')
# 13:10 bilby INFO    : mass_1=Constraint(minimum=10, maximum=80, name='mass_1', latex_label='$m_1$', unit=None)
# 13:10 bilby INFO    : mass_2=Constraint(minimum=10, maximum=80, name='mass_2', latex_label='$m_2$', unit=None)
# 13:10 bilby INFO    : luminosity_distance=1587.4093196389506
# 13:10 bilby INFO    : phase=0.0
# 13:10 bilby INFO    : geocent_time=1126259460.0
# 13:10 bilby INFO    : Analysis likelihood class: <class 'bilby.gw.likelihood.base.GravitationalWaveTransient'>
# 13:10 bilby INFO    : Analysis likelihood noise evidence: -20676.586002727097
# 13:10 bilby INFO    : Single likelihood evaluation took 6.589e-03 s
# 13:10 bilby INFO    : Using sampler Dynesty with kwargs {'nlive': 1000, 'bound': 'live', 'sample': 'act-walk', 'periodic': None, 'reflective': None, 'update_interval': 600, 'first_update': None, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'gradient': None, 'grad_args': None, 'grad_kwargs': None, 'compute_jac': False, 'enlarge': None, 'bootstrap': None, 'walks': 100, 'facc': 0.2, 'slices': None, 'fmove': 0.9, 'max_move': 100, 'update_func': None, 'ncdim': None, 'blob': False, 'save_history': False, 'history_filename': None, 'maxiter': None, 'maxcall': None, 'dlogz': 0.1, 'logl_max': inf, 'n_effective': None, 'add_live': True, 'print_progress': True, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x1547a70d0>>, 'save_bounds': False, 'checkpoint_file': None, 'checkpoint_every': 60, 'resume': False}
# 13:10 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 13:10 bilby INFO    : Using dynesty version 2.1.1
# 13:10 bilby INFO    : Using the bilby-implemented rwalk sampling tracking the autocorrelation function and thinning by 2 with maximum length 10000
# 13:10 bilby INFO    : Reading resume file outdir/GW150914_resume.pickle
# 13:10 bilby INFO    : Resume file successfully loaded.
# 12615it [00:00, ?it/s]
# 13:11 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:23 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:35 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:45 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:56 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:06 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:16 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:40 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:50 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:00 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:10 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:21 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:32 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:43 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:54 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 16:05 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 16:18 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 16:34 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 16:44 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 21:33 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 21:46 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 21:59 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:11 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:23 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:34 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:46 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:59 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 23:11 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 03:40 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 09:32 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 10:49 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 11:52 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:02 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:15 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:27 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:52 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:03 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:15 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:32 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:50 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:02 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:14 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:25 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:37 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:53 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:04 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:19 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:30 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:40 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 15:59 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 16:15 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 16:25 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 16:38 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 16:50 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 17:02 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 17:14 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 17:50 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 18:22 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 20:48 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 20:58 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 21:15 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 21:27 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 21:52 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:07 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:20 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:32 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:47 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 22:58 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 23:34 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 00:34 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 04:22 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 05:53 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 09:55 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 10:14 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 10:45 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 11:18 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 11:44 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:02 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:17 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:28 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:41 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 12:55 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:06 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:23 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:39 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 13:52 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:06 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:23 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:33 bilby INFO    : Written checkpoint file outdir/GW150914_resume.pickle
# 14:33 bilby INFO    : Rejection sampling nested samples to obtain 4987 posterior samples
# 14:33 bilby INFO    : Sampling time: 4 days, 0:31:02.985438
# 14:34 bilby INFO    : Computing per-detector log likelihoods.
#   0%|          | 0/4987 [00:00<?, ?it/s]
# 14:34 bilby INFO    : Reconstructing marginalised parameters.
#   0%|          | 0/4987 [00:00<?, ?it/s]
# 14:38 bilby INFO    : Generating sky frame parameters.
#   0%|          | 0/4987 [00:00<?, ?it/s]
# 14:38 bilby INFO    : Computing SNRs for every sample.
#   0%|          | 0/4987 [00:00<?, ?it/s]
# 14:38 bilby INFO    : Summary of results:
# nsamples: 4987
# ln_noise_evidence: -20676.586
# ln_evidence: -20396.693 +/-  0.133
# ln_bayes_factor: 279.893 +/-  0.133
